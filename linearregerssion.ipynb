# %%
import numpy  as np
import pandas as pd
from matplotlib import  pyplot as plt

# %%
df = pd.read_csv('Salary_dataset.csv')

# %%
plt.scatter(df.YearsExperience,df.Salary,marker='*',color='red')
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %%
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
reg = linear_model.LinearRegression()

# %%
reg.fit(df[['YearsExperience']],df.Salary)
# Out:
# LinearRegression()

# %%
X = reg.predict([[5]])
# Out:
# C:\Users\kripa\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
print(X)
# Out:
# [72098.0155738]

# %%
df1 = pd.read_csv('test_data.csv')
df1
# Out:
#    YearsExperience
# 0             6.00
# 1             9.00
# 2             1.50
# 3             2.00
# 4             8.00
# 5             8.75

# %%
p = reg.predict(df1)

# %%
Accuracy=reg.score(df[['YearsExperience']],df.Salary)
print('Accuracy=', Accuracy)
# Out:
# Accuracy= 0.9569566641435086

# %%
df1['Salary']=p
df1
# Out:
#    YearsExperience         Salary
# 0             6.00   81547.977895
# 1             9.00  109897.864860
# 2             1.50   39023.147449
# 3             2.00   43748.128609
# 4             8.00  100447.902538
# 5             8.75  107535.374279

# %%
#%matplotlib inline
#df = pd.read_csv('/content/drive/MyDrive/ML/linea_reg_house.csv')
#from matplotlib import  pyplot as plt
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
plt.scatter(df.YearsExperience,df.Salary, marker='*',color='green')
plt.plot(df.YearsExperience, reg.predict(df[['YearsExperience']]), color='black')
